# %% [markdown]
# <a href="https://colab.research.google.com/github/leeet1004835/colab/blob/main/0402_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 臺灣銀行委辦 AI 人才進階訓練
#
# > 隨堂練習：Python 程式設計（一），2026-03-19
#
# [郭耀仁](https://hahow.in/@tonykuoyj?tr=tonykuoyj) | <yaojenkuo@ntu.edu.tw>

# %% [markdown]
# ## 練習題指引
#
# - 單選題：覺得第一個選項正確，就將 `None` 改寫為 1，覺得第二個選項正確，就將 `None` 改寫為 2，覺得第三個選項正確，就將 `None` 改寫 3，覺得第四個選項正確，就將 `None` 改寫 4
# - 練習題已經給定函數、類別、預期輸入或參數名稱，我們只需要寫作程式區塊。同時也給定函數的類別提示，說明預期輸入以及預期輸出的類別。
# - 說明（Docstring）會描述測試如何進行，閱讀說明能夠暸解預期輸入以及預期輸出之間的關係，幫助我們更快解題。
# - 請在 `### BEGIN SOLUTION` 與 `### END SOLUTION` 這兩個註解之間寫作函數或者類別的程式區塊。
# - 將預期輸出放置在 `return` 保留字之後，若只是用 `print()` 函數將預期輸出印出無法通過測試。
# - 語法錯誤（`SyntaxError`）或縮排錯誤（`IndentationError`）等將會導致測試失效，測試之前應該先在筆記本使用函數觀察是否與說明（Docstring）描述的功能相符。
# - 執行測試的步驟：
#     1. 點選右上角 Connect
#     2. 點選上方選單的 Runtime -> Restart and run all -> Yes -> Run anyway
#     3. 移動到 Google Colab 的最後一個儲存格看批改測試結果。

# %% [markdown]
# ## 01. 下列何者不屬於現代資料科學的應用場景？
#
# 1. Communicate.
# 2. Model.
# 3. Tidy.
# 4. Transition.

# %%
answer_01 = None

# %% [markdown]
# ## 02. 下列何者不是寫作與執行 Python 必備的軟體？
#
# 1. 純文字編輯器。
# 2. 整合開發環境。
# 3. 終端機。
# 4. Python 直譯器。

# %%
answer_02 = None

# %% [markdown]
# ## 03. 檢視 Python 禪學，下列何者並不是其中的禪學？
#
# 1. Beautiful is better than ugly.
# 2. Simple is better than complex.
# 3. Nested is better than flat.
# 4. Now is better than never.

# %%
answer_03 = None

# %% [markdown]
# ## 04. 檢視保留字清單，下列何者不是 Python 保留字？
#
# 1. `False`
# 2. `True`
# 3. `global`
# 4. `local`

# %%
answer_04 = None

# %% [markdown]
# ## 05. 檢視內建函數頁面 <https://docs.python.org/3/library/functions.html>，下列何者不是內建函數？
#
# 1. `mean()`
# 2. `sum()`
# 3. `max()`
# 4. `min()`

# %%
answer_05 = None

# %% [markdown]
# ## 06. 哈囉 Python
#
# 定義函數 `say_hello_to_python()` 將 `"Hello Python!"` 回傳。

# %%
def say_hello_to_python() -> str:
    """
    >>> say_hello_to_python()
    'Hello Python!'
    """
    ### BEGIN SOLUTION

    ### END SOLUTION

# %% [markdown]
# ## 07. 自己的英文名字
#
# 定義函數 `say_my_name()` 將自己的英文名字回傳。

# %%
def say_my_name() -> str:
    """
    >>> say_my_name()
    'Tony'
    >>> say_my_name()
    'Tommy'
    >>> say_my_name()
    ...
    """
    ### BEGIN SOLUTION

    ### END SOLUTION

# %% [markdown]
# ## 08. 最喜歡的整數
#
# 定義函數 `return_my_favorite_integer()` 將自己最喜歡的整數回傳。

# %%
def return_my_favorite_integer() -> int:
    """
    >>> return_my_favorite_integer()
    24
    >>> return_my_favorite_integer()
    7
    >>> return_my_favorite_integer()
    ...
    """
    ### BEGIN SOLUTION

    ### END SOLUTION

# %% [markdown]
# ## 09. 第一句 Python 禪學
#
# 定義函數 `return_the_first_zen_of_python()` 將第一句 Python 禪學（The Zen of Python）回傳。
#
# ```
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
# ```

# %%
def return_the_first_zen_of_python() -> str:
    """
    >>> return_the_first_zen_of_python()
    'Beautiful is better than ugly.'
    """
    ### BEGIN SOLUTION

    ### END SOLUTION

# %% [markdown]
# ## 10. 最喜歡的一句 Python 禪學
#
# 定義函數 `return_my_favorite_zen_of_python()` 將自己最喜歡的一句 Python 禪學（The Zen of Python）回傳。
#
# ```
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
# ```

# %%
def return_my_favorite_zen_of_python() -> str:
    """
    >>> return_my_favorite_zen_of_python()
    'Now is better than never.'
    >>> return_my_favorite_zen_of_python()
    'Readability counts.'
    >>> return_my_favorite_zen_of_python()
    ...
    """
    ### BEGIN SOLUTION

    ### END SOLUTION

# %% [markdown]
# ## 練習題到此結束

# %%
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-hahow-pythonfiftyplus/main/01-introduction/zen_of_python.txt

# %%
import unittest

def run_suite(test_class):
    suite = unittest.TestLoader().loadTestsFromTestCase(test_class)
    runner = unittest.TextTestRunner(verbosity=2)
    test_results = runner.run(suite)
    number_of_failures = len(test_results.failures)
    number_of_errors = len(test_results.errors)
    number_of_test_runs = test_results.testsRun
    number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
    chapter_percentage = number_of_successes * 100 / number_of_test_runs
    print("你的練習題完成率為 ... {:.2f}% ({}/{})".format(chapter_percentage, number_of_successes, number_of_test_runs))

class TestDayOne(unittest.TestCase):
    def test_01(self):
        self.assertEqual(answer_01, 4)
    def test_02(self):
        self.assertEqual(answer_02, 2)
    def test_03(self):
        self.assertEqual(answer_03, 3)
    def test_04(self):
        self.assertEqual(answer_04, 4)
    def test_05(self):
        self.assertEqual(answer_05, 1)
    def test_06_say_hello_to_python(self):
        self.assertEqual(say_hello_to_python(), 'Hello Python!')
    def test_07_say_my_name(self):
        self.assertTrue(isinstance(say_my_name(), str))
    def test_08_return_my_favorite_integer(self):
        self.assertTrue(isinstance(return_my_favorite_integer(), int))
    def test_09_return_the_first_zen_of_python(self):
        self.assertEqual(return_the_first_zen_of_python(), 'Beautiful is better than ugly.')
    def test_10_return_my_favorite_zen_of_python(self):
        my_favorite_zen_of_python = return_my_favorite_zen_of_python()
        file_path = "zen_of_python.txt"
        with open(file_path, 'r') as f:
            zen_of_py = f.readlines()
        zen_of_py = [s.strip() for s in zen_of_py]
        self.assertIsInstance(my_favorite_zen_of_python, str)
        self.assertTrue(my_favorite_zen_of_python in zen_of_py)

run_suite(TestDayOne)
