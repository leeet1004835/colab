# %% [markdown]
# <a href="https://colab.research.google.com/github/leeet1004835/colab/blob/main/0416_data_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
print(np.__version__) # 屬性檢查版本號
print(np.__file__) #  屬性檢查安裝路徑
# Out:
# 2.0.2
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py
