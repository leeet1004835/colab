# %% [markdown]
# <a href="https://colab.research.google.com/github/leeet1004835/colab/blob/main/07_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 臺灣銀行委辦 AI 人才進階訓練
#
# > 隨堂練習：人工智慧，2026-05-13
#
# [郭耀仁](https://hahow.in/@tonykuoyj?tr=tonykuoyj) | <yaojenkuo@ntu.edu.tw>

# %% [markdown]
# ## 練習題指引
#
# - 單選題：覺得第一個選項正確，就將 `None` 改寫為 1，覺得第二個選項正確，就將 `None` 改寫為 2，覺得第三個選項正確，就將 `None` 改寫 3，覺得第四個選項正確，就將 `None` 改寫 4
# - 練習題已經給定函數、類別、預期輸入或參數名稱，我們只需要寫作程式區塊。同時也給定函數的類別提示，說明預期輸入以及預期輸出的類別。
# - 說明（Docstring）會描述測試如何進行，閱讀說明能夠暸解預期輸入以及預期輸出之間的關係，幫助我們更快解題。
# - 請在 `### BEGIN SOLUTION` 與 `### END SOLUTION` 這兩個註解之間寫作函數或者類別的程式區塊。
# - 將預期輸出放置在 `return` 保留字之後，若只是用 `print()` 函數將預期輸出印出無法通過測試。
# - 語法錯誤（`SyntaxError`）或縮排錯誤（`IndentationError`）等將會導致測試失效，測試之前應該先在筆記本使用函數觀察是否與說明（Docstring）描述的功能相符。
# - 執行測試的步驟：
#     1. 點選右上角 Connect
#     2. 點選上方選單的 Runtime -> Restart and run all -> Yes -> Run anyway
#     3. 移動到 Google Colab 的最後一個儲存格看批改測試結果。

# %% [markdown]
# ## 01. 關於機器學習與深度學習的比較，下列敘述何者正確？
#
# 1. 深度學習演算法在電腦視覺方面的表現比機器學習演算法突出。
# 2. 深度學習演算法在自然語言方面的表現比機器學習演算法突出。
# 3. 深度學習不需要使用者直接進行特徵工程。
# 4. 機器學習需要使用者進行特徵工程。
# 5. 以上皆是。

# %%
answer_01 = 5

# %% [markdown]
# ## 02. 下列何者是 ChatGPT 中 "T" 的全稱？
#
# 1. Transportation
# 2. Transformer
# 3. Transfer
# 4. Treasury

# %%
answer_02 = 2

# %% [markdown]
# ## 03. 下列關於人工智慧、大型語言模型的敘述何者有誤？
#
# 1. 人工智慧、大型語言模型跟機器學習或深度學習是獨立無相關的學科。
# 2. 「大型語言模型」中的形容「大型」指的是參數數量極多。
# 3. ChatGPT、Gemini、Grok、Claude 等都是大型語言模型的服務。
# 4. 大型語言模型可以視為深度學習的一種模型。

# %%
answer_03 = 1

# %% [markdown]
# ## 04. 下列關於自然語言的敘述何者正確？
#
# 1. 讓電腦理解自然語言是非常簡單的任務。
# 2. 傳統機器學習的編碼轉換例如 One-hot encoder、Dummy encoder 就可以解決自然語言的編碼轉換問題。
# 3. 理想的編碼轉換應該要能讓詞向量反映「同義詞」、「反義詞」。
# 4. 大型語言模型只需要解決編碼轉換問題即可。

# %%
answer_04 = 3
# 4.編碼轉換和連貫性的問題

# %% [markdown]
# ## 05. 有關大型語言模型的核心 Transformer，下列敘述何者正確？
#
# 1. 除了 Transformer 外其他的深度學習模型都無法解決自然語言的問題。
# 2. 以 Attention 注意力機制解決詞彙連貫性的關鍵問題。
# 3. 以 Attention 注意力機制解決詞向量編碼轉換的關鍵問題。
# 4. Transformer 不能歸類為深度學習模型。

# %%
answer_05 = 2
# 4.Transformer為深度學習模型

# %% [markdown]
# ## 06. 下列哪一個深度學習的框架是目前開發者的首選？
#
# 1. Scikit-Learn
# 2. Theano
# 3. TensorFlow
# 4. PyTorch
# 5. Keras

# %%
answer_06 = 4

# %% [markdown]
# ## 07. 下列何者屬於大型語言模型的應用場景？
#
# 1. 翻譯。
# 2. 聊天機器人。
# 3. 輸入文字輸出圖片。
# 4. 輸入音訊輸出文字。
# 5. 以上皆是。

# %%
answer_07 = 5

# %% [markdown]
# ## 08. 下列關於不同深度學習模型的敘述何者正確？
#
# 1. 全連接神經網路（FNN）擅長表格式資料。
# 2. 卷積神經網路（CNN）擅長圖片資料。
# 3. 遞歸神經網路（RNN）擅長自然語言。
# 4. 長短期記憶模型（LSTM）擅長自然語言。
# 5. Transformer 擅長自然語言。
# 6. 以上皆是。

# %%
answer_08 = 6

# %% [markdown]
# ## 09. 下圖的深度學習模型共有幾個係數與誤差要進行最適化？
#
# ![](https://raw.githubusercontent.com/datainpoint/classroom-fintech-bot-2026/refs/heads/main/nn_01.png)
#
# 1. 48
# 2. 63
# 3. 65
# 4. 66

# %%
answer_09 = 3
# w1=2*16=32
# b1=16
# 32+16+16=64+1=65

# %% [markdown]
# ## 10. 下圖的深度學習模型共有幾個係數與誤差要進行最適化？
#
# ![](https://raw.githubusercontent.com/datainpoint/classroom-fintech-bot-2026/refs/heads/main/nn_02.png)
#
# 1. 48
# 2. 49
# 3. 56
# 4. 57

# %%
answer_10 = 4
# 48+8=56+1=57

# %% [markdown]
# ## 練習題到此結束

# %%
import unittest

def run_suite(test_class):
    suite = unittest.TestLoader().loadTestsFromTestCase(test_class)
    runner = unittest.TextTestRunner(verbosity=2)
    test_results = runner.run(suite)
    number_of_failures = len(test_results.failures)
    number_of_errors = len(test_results.errors)
    number_of_test_runs = test_results.testsRun
    number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
    chapter_percentage = number_of_successes * 100 / number_of_test_runs
    print("你的練習題完成率為 ... {:.2f}% ({}/{})".format(chapter_percentage, number_of_successes, number_of_test_runs))

class TestDaySeven(unittest.TestCase):
    def test_01(self):
        self.assertEqual(answer_01, 4)
    def test_02(self):
        self.assertEqual(answer_02, 2)
    def test_03(self):
        self.assertEqual(answer_03, 1)
    def test_04(self):
        self.assertEqual(answer_04, 3)
    def test_05(self):
        self.assertEqual(answer_05, 2)
    def test_06(self):
        self.assertEqual(answer_06, 4)
    def test_07(self):
        self.assertEqual(answer_07, 5)
    def test_08(self):
        self.assertEqual(answer_08, 6)
    def test_09(self):
        self.assertEqual(answer_09, 3)
    def test_10(self):
        self.assertEqual(answer_10, 4)

run_suite(TestDaySeven)
