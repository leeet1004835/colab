# %% [markdown]
# <a href="https://colab.research.google.com/github/leeet1004835/colab/blob/main/Copy_of_Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 賦值
hello_world = "Hello world!" #hello_world refers to a str: "Hello world!"
print(hello_world)
# Out:
# Hello world!

# %%
key_words = "keywords"
help(key_words)
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
returnn = "Book return"

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
a_negative_number = -7788
print(abs(a_negative_number))
print(bin(a_negative_number))
print(complex(a_negative_number))
# Out:
# 7788
# -0b1111001101100
# (-7788+0j)

# %%
from statistics import median
median([1, 2, 3, 4, 5])
# Out:
# 3

# %%
# Positional arguments
print(pow(5, 2))
print(pow(2, 5))
# Out:
# 25
# 32

# %%
# Keyword arguments
print(pow(5, 2))
print(pow(exp=2, base=5)) # 5 as base, 2 as exp
# Out:
# 25
# 25

# %%
from statistics import mean
from statistics import median
# Request: A user-defined function 'descriptive_stats()'

def descriptive_stats(xi) -> dict:
    '''
    使用者定義的函數
    Returns minimum value, maximum value, mean, and median with a dict given a list of numbers.
    '''
    # line a
    # line b
    # line c
    min_xi = min(xi)
    max_xi = max(xi)
    mean_xi = mean(xi)
    median_xi = mean(xi)
    output = {
        "minimum": min_xi,
        "maximum": max_xi,
        "mean": mean_xi,
        "median": mean_xi
    }
    return output

x1 = [1, 2, 3, 4, 5]
x2 = [2, 4, 6, 8, 10]
x3 = [1, 3, 5, 7, 9, 11, 13]
print(descriptive_stats(x1)) # line a-c
print(descriptive_stats(x2)) # line a-c
print(descriptive_stats(x3)) # line a-c
# Out:
# {'minimum': 1, 'maximum': 5, 'mean': 3, 'median': 3}
# {'minimum': 2, 'maximum': 10, 'mean': 6, 'median': 6}
# {'minimum': 1, 'maximum': 13, 'mean': 7, 'median': 7}

# %%
print(sum(x1))
# Out:
# 15

# %%
sum = "55" + "66"
print(sum)
# Out:
# 5566
