# %% [markdown]
# # 臺灣銀行委辦 AI 人才進階訓練
#
# > 隨堂練習：Python 程式設計（二），2026-03-26
#
# [郭耀仁](https://hahow.in/@tonykuoyj?tr=tonykuoyj) | <yaojenkuo@ntu.edu.tw>

# %% [markdown]
# ## 練習題指引
#
# - 單選題：覺得第一個選項正確，就將 `None` 改寫為 1，覺得第二個選項正確，就將 `None` 改寫為 2，覺得第三個選項正確，就將 `None` 改寫 3，覺得第四個選項正確，就將 `None` 改寫 4
# - 練習題已經給定函數、類別、預期輸入或參數名稱，我們只需要寫作程式區塊。同時也給定函數的類別提示，說明預期輸入以及預期輸出的類別。
# - 說明（Docstring）會描述測試如何進行，閱讀說明能夠暸解預期輸入以及預期輸出之間的關係，幫助我們更快解題。
# - 請在 `### BEGIN SOLUTION` 與 `### END SOLUTION` 這兩個註解之間寫作函數或者類別的程式區塊。
# - 將預期輸出放置在 `return` 保留字之後，若只是用 `print()` 函數將預期輸出印出無法通過測試。
# - 語法錯誤（`SyntaxError`）或縮排錯誤（`IndentationError`）等將會導致測試失效，測試之前應該先在筆記本使用函數觀察是否與說明（Docstring）描述的功能相符。
# - 執行測試的步驟：
#     1. 點選右上角 Connect
#     2. 點選上方選單的 Runtime -> Restart and run all -> Yes -> Run anyway
#     3. 移動到 Google Colab 的最後一個儲存格看批改測試結果。

# %% [markdown]
# ## 01. 下列何者不是 Python 的基礎資料類別？
#
# 1. `int`
# 2. `bool`
# 3. `NoneType`
# 4. `logical`
# 5. `str`
# 6. `float`

# %%
answer_01 = 4

# %% [markdown]
# ## 02. 下列何者不是 Python 的基礎資料結構？
#
# 1. `list`
# 2. `DataFrame`
# 3. `tuple`
# 4. `dict`
# 5. `set`

# %%
answer_02 = 2

# %% [markdown]
# ## 03. 下列何者是 Python 中能夠以「鍵」取「值」的基礎資料結構？
#
# 1. `list`
# 2. `tuple`
# 3. `dict`
# 4. `set`
# 5. `hash`

# %%
answer_03 = 3

# %% [markdown]
# ## 04. 轉換公里為英里
#
# 定義函數 `convert_km_to_mile()` 能夠將以公里（km）為單位的距離轉換為以英里（mile）為單位的距離。
#
# \begin{equation}
# 1 \; \text{km} = 0.62137 \; \text{mile}
# \end{equation}

# %%
def convert_km_to_mile(km: float) -> float:
    """
    >>> convert_km_to_mile(42.195) # a full marathon
    26.21870715
    >>> convert_km_to_mile(21.095) # a half marathon
    13.10780015
    """
    ### BEGIN SOLUTION
    mile = km * 0.62137
    return mile
    ### END SOLUTION

# %%
print(convert_km_to_mile(42.195))
print(convert_km_to_mile(21.095))
# Out:
# 26.21870715
# 13.10780015

# %% [markdown]
# ## 05. 轉換華氏為攝氏
#
# 定義函數 `convert_fahrenheit_to_celsius()` 能夠將以華氏為單位的溫度轉換為以攝氏為單位的溫度。
#
# \begin{equation}
# \text{Celsius}(^{\circ} \text{C}) = (\text{Fahrenheit}(^{\circ} \text{F}) - 32) \times \frac{5}{9}
# \end{equation}

# %%
def convert_fahrenheit_to_celsius(x: int) -> float:
    """
    >>> convert_fahrenheit_to_celsius(212)
    100.0
    >>> convert_fahrenheit_to_celsius(32)
    0.0
    """
    ### BEGIN SOLUTION
    c = (x - 32) * 5 / 9
    return c
    ### END SOLUTION

# %%
convert_fahrenheit_to_celsius(212)
# Out:
# 100.0

# %% [markdown]
# ## 06. 顯示逗號與兩位小數格式
#
# 定義函數 `show_integer_with_commas_and_digits()` 能夠將整數以千分位逗號與兩位浮點數顯示。

# %%
def show_integer_with_commas_and_digits(x: int) -> str:
    """
    >>> show_integer_with_commas_and_digits(1000)
    '1,000.00'
    >>> show_integer_with_commas_and_digits(10000)
    '10,000.00'
    >>> show_integer_with_commas_and_digits(100000)
    '100,000.00'
    """
    ### BEGIN SOLUTION
    #output = "{:,.2f}".format(x)
    output = f"{x:,.2f}"
    return output
    ### END SOLUTION

# %%
show_integer_with_commas_and_digits(1000)
# Out:
# '1,000.00'

# %% [markdown]
# ## 07. 是否為因數
#
# 自行定義函數 `is_a_divisor()` 能夠判斷輸入的兩個正整數中，前者是否為後者的因數（前者能否把後者整除）。

# %%
def is_a_divisor(x: int, y: int) -> bool:
    """
    >>> is_a_divisor(1, 3)
    True
    >>> is_a_divisor(2, 3)
    False
    >>> is_a_divisor(3, 3)
    True
    >>> is_a_divisor(1, 4)
    True
    >>> is_a_divisor(2, 4)
    True
    >>> is_a_divisor(3, 4)
    False
    >>> is_a_divisor(4, 4)
    True
    """
    ### BEGIN SOLUTION

    # modulo = y % x #餘數
    # return modulo

    # modulo = y % x #前者能否把後者整除，餘數為0
    # if modulo == 0:
    #    return True
    # else:
    #   return False

    modulo = y % x #前者能否把後者整除，餘數為0
    return modulo == 0
    ### END SOLUTION

# %%
is_a_divisor(2, 3)
# Out:
# False

# %% [markdown]
# ## 08. 取出第一個與最後一個元素
#
# 定義函數 `retrieve_the_first_and_last_element()` 能夠將輸入 `list` 的第一個資料與最後一個資料取出，並且用 `dict` 的 keys 標註。

# %%
def retrieve_the_first_and_last_element(x: list) -> dict:
    """
    >>> retrieve_the_first_and_last_element([2, 3, 5, 7, 11])
    {'first': 2, 'last': 11}
    >>> retrieve_the_first_and_last_element(["Python", "Reticulate", "Anaconda"])
    {'first': 'Python', 'last': 'Anaconda'}
    """
    ### BEGIN SOLUTION

    # first_element = x[0]
    # last_element = x[-1]
    # return first_element, last_element

    first_element = x[0]
    last_element = x[-1]
    output = {
        "first": first_element,
        "last": last_element
        }
    return output
    ### END SOLUTION

# %%
print(retrieve_the_first_and_last_element([2, 3, 5, 7, 11]))
print(retrieve_the_first_and_last_element(["Python", "Reticulate", "Anaconda"]))
# Out:
# {'first': 2, 'last': 11}
# {'first': 'Python', 'last': 'Anaconda'}

# %% [markdown]
# ## 09. 台北市行政區郵遞區號
#
# 定義函數 `find_taipei_citys_zip_code()` 能輸入台北市的行政區名稱，回傳三碼的郵遞區號。
#
# 來源：[臺北市行政區劃](https://zh.wikipedia.org/wiki/%E8%87%BA%E5%8C%97%E5%B8%82%E8%A1%8C%E6%94%BF%E5%8D%80%E5%8A%83)

# %%
def find_taipei_citys_zip_code(area_name: str) -> int:
    """
    >>> find_taipei_citys_zip_code("中正區")
    100
    >>> find_taipei_citys_zip_code("大同區")
    103
    >>> find_taipei_citys_zip_code("中山區")
    104
    """
    ### BEGIN SOLUTION

    # if area_name == "中正區":
    #     return 100
    # elif area_name == "大同區":
    #     return 103
    # elif area_name == "中山區":
    #     return 104
    # elif area_name == "松山區":
    #     return 105
    # elif area_name == "大安區":
    #     return 106
    # elif area_name == "萬華區":
    #     return 108
    # elif area_name == "信義區":
    #     return 110
    # elif area_name == "士林區":
    #     return 111
    # elif area_name == "北投區":
    #     return 112
    # elif area_name == "內湖區":
    #     return 114
    # elif area_name == "南港區":
    #     return 115
    # elif area_name == "文山區":
    #     return 116
    # else:
    #     return None

    area_dict = {
    "中正區": 100,
    "大同區": 103,
    "中山區": 104,
    "松山區": 105,
    "大安區": 106,
    "萬華區": 108,
    "信義區": 110,
    "士林區": 111,
    "北投區": 112,
    "內湖區": 114,
    "南港區": 115,
    "文山區": 116
    }
    return area_dict[area_name]

    ### END SOLUTION

# %%
find_taipei_citys_zip_code("中正區")
# Out:
# 100

# %% [markdown]
# ## 10. 判斷資料類別
#
# 定義函數 `check_data_type()` 能夠將輸入的資料類別以 `str` 輸出。

# %%
def check_data_type(x) -> str:
    """
    >>> check_data_type(0)
    'int'
    >>> check_data_type(1.0)
    'float'
    >>> check_data_type(False)
    'bool'
    >>> check_data_type(True)
    'bool'
    >>> check_data_type('5566')
    'str'
    >>> check_data_type(None)
    'NoneType'
    """
    ### BEGIN SOLUTION
    if isinstance(x, bool):
        return "bool"
    elif isinstance(x, int):
        return "int"
    elif isinstance(x, float):
        return "float"
    elif isinstance(x, str):
        return "str"
    elif isinstance(x, type(None)):
        return "NoneType"
    ### END SOLUTION

# %%
check_data_type(5566)
# Out:
# 'int'

# %% [markdown]
# ## 練習題到此結束

# %%
import unittest

def run_suite(test_class):
    suite = unittest.TestLoader().loadTestsFromTestCase(test_class)
    runner = unittest.TextTestRunner(verbosity=2)
    test_results = runner.run(suite)
    number_of_failures = len(test_results.failures)
    number_of_errors = len(test_results.errors)
    number_of_test_runs = test_results.testsRun
    number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
    chapter_percentage = number_of_successes * 100 / number_of_test_runs
    print("你的練習題完成率為 ... {:.2f}% ({}/{})".format(chapter_percentage, number_of_successes, number_of_test_runs))

class TestDayTwo(unittest.TestCase):
    def test_01(self):
        self.assertEqual(answer_01, 4)
    def test_02(self):
        self.assertEqual(answer_02, 2)
    def test_03(self):
        self.assertEqual(answer_03, 3)
    def test_04_convert_km_to_mile(self):
        self.assertTrue(convert_km_to_mile(42.195) > 26)
        self.assertTrue(convert_km_to_mile(42.195) < 27)
        self.assertTrue(convert_km_to_mile(21.095) > 13)
        self.assertTrue(convert_km_to_mile(21.095) < 14)
    def test_05_convert_fahrenheit_to_celsius(self):
        self.assertTrue(convert_fahrenheit_to_celsius(212) >= 100.0)
        self.assertTrue(convert_fahrenheit_to_celsius(32) >= 0.0)
    def test_06_show_integer_with_commas_and_digits(self):
        self.assertEqual(show_integer_with_commas_and_digits(1000), "1,000.00")
        self.assertEqual(show_integer_with_commas_and_digits(10000), "10,000.00")
        self.assertEqual(show_integer_with_commas_and_digits(100000), "100,000.00")
        self.assertEqual(show_integer_with_commas_and_digits(1000000), "1,000,000.00")
        self.assertEqual(show_integer_with_commas_and_digits(10000000), "10,000,000.00")
    def test_07_is_a_divisor(self):
        self.assertFalse(is_a_divisor(2, 3))
        self.assertFalse(is_a_divisor(3, 4))
        self.assertTrue(is_a_divisor(1, 3))
        self.assertTrue(is_a_divisor(3, 3))
        self.assertTrue(is_a_divisor(1, 4))
        self.assertTrue(is_a_divisor(2, 4))
        self.assertTrue(is_a_divisor(4, 4))
    def test_08_retrieve_the_first_and_last_element(self):
        the_first_and_last_element = retrieve_the_first_and_last_element([2, 3, 5, 7, 11])
        self.assertEqual(the_first_and_last_element["first"], 2)
        self.assertEqual(the_first_and_last_element["last"], 11)
        the_first_and_last_element = retrieve_the_first_and_last_element([2, 3, 5])
        self.assertEqual(the_first_and_last_element["first"], 2)
        self.assertEqual(the_first_and_last_element["last"], 5)
        the_first_and_last_element = retrieve_the_first_and_last_element(["Python", "Reticulate", "Anaconda"])
        self.assertEqual(the_first_and_last_element["first"], "Python")
        self.assertEqual(the_first_and_last_element["last"], "Anaconda")
        the_first_and_last_element = retrieve_the_first_and_last_element(["Python", "Reticulate", "Anaconda", "Skywalker"])
        self.assertEqual(the_first_and_last_element["first"], "Python")
        self.assertEqual(the_first_and_last_element["last"], "Skywalker")
    def test_09_find_taipei_citys_zip_code(self):
        self.assertEqual(find_taipei_citys_zip_code("中正區"), 100)
        self.assertEqual(find_taipei_citys_zip_code("大同區"), 103)
        self.assertEqual(find_taipei_citys_zip_code("中山區"), 104)
        self.assertEqual(find_taipei_citys_zip_code("松山區"), 105)
        self.assertEqual(find_taipei_citys_zip_code("大安區"), 106)
        self.assertEqual(find_taipei_citys_zip_code("萬華區"), 108)
        self.assertEqual(find_taipei_citys_zip_code("信義區"), 110)
        self.assertEqual(find_taipei_citys_zip_code("內湖區"), 114)
        self.assertEqual(find_taipei_citys_zip_code("南港區"), 115)
        self.assertEqual(find_taipei_citys_zip_code("北投區"), 112)
        self.assertEqual(find_taipei_citys_zip_code("士林區"), 111)
        self.assertEqual(find_taipei_citys_zip_code("文山區"), 116)
    def test_10_check_data_type(self):
        self.assertEqual(check_data_type(0), 'int')
        self.assertEqual(check_data_type(1.0), 'float')
        self.assertEqual(check_data_type(False), 'bool')
        self.assertEqual(check_data_type(True), 'bool')
        self.assertEqual(check_data_type('5566'), 'str')
        self.assertEqual(check_data_type(None), 'NoneType')

run_suite(TestDayTwo)
# Out:
# test_01 (__main__.TestDayTwo.test_01) ... ok
# test_02 (__main__.TestDayTwo.test_02) ... ok
# test_03 (__main__.TestDayTwo.test_03) ... ok
# test_04_convert_km_to_mile (__main__.TestDayTwo.test_04_convert_km_to_mile) ... ok
# test_05_convert_fahrenheit_to_celsius (__main__.TestDayTwo.test_05_convert_fahrenheit_to_celsius) ... ok
# test_06_show_integer_with_commas_and_digits (__main__.TestDayTwo.test_06_show_integer_with_commas_and_digits) ... ok
# test_07_is_a_divisor (__main__.TestDayTwo.test_07_is_a_divisor) ... ok
# test_08_retrieve_the_first_and_last_element (__main__.TestDayTwo.test_08_retrieve_the_first_and_last_element) ... ok
# test_09_find_taipei_citys_zip_code (__main__.TestDayTwo.test_09_find_taipei_citys_zip_code) ... ok
# test_10_check_data_type (__main__.TestDayTwo.test_10_check_data_type) ... ok
#
# ----------------------------------------------------------------------
# Ran 10 tests in 0.022s
#
# OK
# 你的練習題完成率為 ... 100.00% (10/10)
