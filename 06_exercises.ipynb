# %% [markdown]
# <a href="https://colab.research.google.com/github/leeet1004835/colab/blob/main/06_exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 臺灣銀行委辦 AI 人才進階訓練
#
# > 隨堂練習：機器學習（二），2026-04-29
#
# [郭耀仁](https://hahow.in/@tonykuoyj?tr=tonykuoyj) | <yaojenkuo@ntu.edu.tw>

# %% [markdown]
# ## 練習題指引
#
# - 單選題：覺得第一個選項正確，就將 `None` 改寫為 1，覺得第二個選項正確，就將 `None` 改寫為 2，覺得第三個選項正確，就將 `None` 改寫 3，覺得第四個選項正確，就將 `None` 改寫 4
# - 練習題已經給定函數、類別、預期輸入或參數名稱，我們只需要寫作程式區塊。同時也給定函數的類別提示，說明預期輸入以及預期輸出的類別。
# - 說明（Docstring）會描述測試如何進行，閱讀說明能夠暸解預期輸入以及預期輸出之間的關係，幫助我們更快解題。
# - 請在 `### BEGIN SOLUTION` 與 `### END SOLUTION` 這兩個註解之間寫作函數或者類別的程式區塊。
# - 將預期輸出放置在 `return` 保留字之後，若只是用 `print()` 函數將預期輸出印出無法通過測試。
# - 語法錯誤（`SyntaxError`）或縮排錯誤（`IndentationError`）等將會導致測試失效，測試之前應該先在筆記本使用函數觀察是否與說明（Docstring）描述的功能相符。
# - 執行測試的步驟：
#     1. 點選右上角 Connect
#     2. 點選上方選單的 Runtime -> Restart and run all -> Yes -> Run anyway
#     3. 移動到 Google Colab 的最後一個儲存格看批改測試結果。

# %% [markdown]
# ## 01. 下列有關簡單梯度遞減的敘述，何者正確？
#
# \begin{equation}
# w := w - \alpha \frac{\partial J}{\partial w}
# \end{equation}
#
# 1. 當梯度為負的時候，$w$ 在下一次迭代更新時會增加。
# 2. 當梯度為正的時候，$w$ 在下一次迭代更新時會減少。
# 3. $\alpha$ 是一個大於零的常數，稱為學習速率。
# 4. $\alpha$ 是一個小於等於零的常數，稱為學習速率。

# %%
answer_01 = None

# %% [markdown]
# ## 02. 下列有關 Sigmoid 函數的敘述，何者有誤？
#
# \begin{equation}
# \sigma(x) = \frac{1}{1 + e^{-x}}
# \end{equation}
#
# 1. Sigmoid 函數的輸入值域介於負無限大與無限大之間。
# 2. Sigmoid 函數的輸出值域介於 0 與 1 之間。
# 3. 輸入 Sigmoid 函數的值愈大，輸出愈接近 `1`
# 4. 輸入 Sigmoid 函數的值愈大，輸出愈接近 `-1`
# 5. 常用來作為模型的啟動函數（Activation function）

# %%
answer_02 = None

# %% [markdown]
# ## 03. 下列有關交叉熵（Cross-entropy）函數的敘述，何者有誤？
#
# \begin{equation}
# J(w) = \frac{1}{m}(-ylog(\hat{p}) - (1-y)log(1-\hat{p}))
# \end{equation}
#
# 1. 當真實的類別為 1，題目撰寫的交叉熵函數只剩下前項。
# 2. 當真實的類別為 0，題目撰寫的交叉熵函數只剩下後項。
# 3. 當真實的類別為 1，$\hat{p}$ 很小的時候，交叉熵函數的輸出為無限大。
# 4. 當真實的類別為 1，$\hat{p}$ 很大的時候，交叉熵函數的輸出為無限大。

# %%
answer_03 = None

# %% [markdown]
# ## 04. 下列有關準確率（Accuracy）的敘述何者有誤？
#
# \begin{equation}
# \text{Accuracy} = \frac{\text{TN} + \text{TP}}{\text{TN} + \text{TP} + \text{FN} + \text{FP}}
# \end{equation}
#
# 1. 是一種常見的分類模型評估指標。
# 2. 計算時分母為所有的觀測值數量。
# 3. 計算時分子為所有的陽性觀測值。
# 4. 並不適用於所有情境的分類模型。

# %%
answer_04 = None

# %% [markdown]
# ## 05. 下列有關 F-Score 的敘述何者正確？
#
# \begin{equation}
# F_{\beta} = (1 + \beta^2) \cdot \frac{precision \cdot recall}{(\beta^2 \cdot precision) + recall}
# \end{equation}
#
# 1. 如果百分百重視精確率，這時代入 $\beta = 0$。
# 2. 如果百分百重視召回率，這時代入 $\beta = \infty$。
# 3. 如果精確率與召回率兩個指標同等重要，這時代入 $\beta = 1$。
# 4. F-Score 在 $\beta = 1$ 的時候稱為 F1-score。
# 5. F-Score 指標愈高，代表模型的表現愈好。
# 6. 以上皆是。

# %%
answer_05 = None

# %% [markdown]
# ## 06. 載入 `titanic_train.csv`
#
# 定義函數 `import_titanic_train()` 將位於工作目錄的 `titanic_train.csv` 載入。
#
# 來源：<https://www.kaggle.com/c/titanic>

# %%
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-fintech-bot-2026/refs/heads/main/titanic_train.csv

# %%
import pandas as pd

def import_titanic_train():
    """
    >>> train = import_titanic_train()
    >>> train.shape
    (891, 12)
    """
    ### BEGIN SOLUTION

    ### END SOLUTION

# %% [markdown]
# ## 07. 擷取目標陣列與特徵矩陣
#
# 定義函數 `extract_target_array_feature_matrix_titanic()` 以 `train.csv` 中的 `Survived` 作為目標陣列 $y$、`Sex` 作為特徵矩陣 $X$，運用下列的 `dict` 將性別轉換為整數。
#
# ```python
# {
#     'female': 0,
#     'male': 1
# }
# ```

# %%
def extract_target_array_feature_matrix_titanic() -> tuple:
    """
    >>> y, X = extract_target_array_feature_matrix_titanic()
    >>> type(y)
    numpy.ndarray
    >>> type(X)
    numpy.ndarray
    >>> y.shape
    (891,)
    >>> X.shape
    (891, 1)
    """
    ### BEGIN SOLUTION

    ### END SOLUTION

# %% [markdown]
# ## 08. 使用梯度遞減找出規則 $w$
#
# 定義函數 `find_w_with_gradient_descent_titanic()` 找出目標陣列 $y$、特徵矩陣 $X$ 之間的規則 $w$

# %%
# 自訂羅吉斯迴歸類別LogitReg
class LogitReg:
    """
    This class defines the vanilla descent algorithm for logistic regression.
    Args:
        fit_intercept (bool): Whether to add intercept for this model.
    """
    def __init__(self, fit_intercept=True):
        self._fit_intercept = fit_intercept
    def sigmoid(self, X):
        """
        This function returns the Sigmoid output as a probability given certain model weights.
        """
        X_w = np.dot(X, self._w)
        p_hat = 1 / (1 + np.exp(-X_w))
        return p_hat
    def find_gradient(self):
        """
        This function returns the gradient given certain model weights.
        """
        m = self._m
        p_hat = self.sigmoid(self._X_train)
        X_train_T = np.transpose(self._X_train)
        gradient = (1/m) * np.dot(X_train_T, p_hat - self._y_train)
        return gradient
    def cross_entropy(self, epsilon=1e-06):
        """
        This function returns the cross entropy given certain model weights.
        """
        m = self._m
        p_hat = self.sigmoid(self._X_train)
        cost_y1 = -np.dot(self._y_train, np.log(p_hat + epsilon))
        cost_y0 = -np.dot(1 - self._y_train, np.log(1 - p_hat + epsilon))
        cross_entropy = (cost_y1 + cost_y0) / m
        return cross_entropy
    def fit(self, X_train, y_train, epochs=10000, learning_rate=0.001):
        """
        This function uses vanilla gradient descent to solve for weights of this model.
        Args:
            X_train (ndarray): 2d-array for feature matrix of training data.
            y_train (ndarray): 1d-array for target vector of training data.
            epochs (int): The number of iterations to update the model weights.
            learning_rate (float): The learning rate of gradient descent.
        """
        self._X_train = X_train.copy()
        self._y_train = y_train.copy()
        m = self._X_train.shape[0]
        self._m = m
        if self._fit_intercept:
            X0 = np.ones((self._m, 1), dtype=float)
            self._X_train = np.concatenate([X0, self._X_train], axis=1)
        n = self._X_train.shape[1]
        self._w = np.random.rand(n)
        n_prints = 10
        print_iter = epochs // n_prints
        for i in range(epochs):
            cross_entropy = self.cross_entropy()
            gradient = self.find_gradient()
            if i % print_iter == 0:
                print("epoch: {:6} - loss: {:.6f}".format(i, cross_entropy))
            self._w -= learning_rate*gradient
        w_ravel = self._w.ravel().copy()
        self.intercept_ = w_ravel[0]
        self.coef_ = w_ravel[1:].reshape(1, -1)
    def predict_proba(self, X_test):
        """
        This function returns predicted probability with weights of this model.
        Args:
            X_test (ndarray): 2d-array for feature matrix of test data.
        """
        m = X_test.shape[0]
        if self._fit_intercept:
            X0 = np.ones((m, 1), dtype=float)
            self._X_test = np.concatenate([X0, X_test], axis=1)
        p_hat_1 = self.sigmoid(self._X_test).reshape(-1, 1)
        p_hat_0 = 1 - p_hat_1
        proba = np.concatenate([p_hat_0, p_hat_1], axis=1)
        return proba
    def predict(self, X_test):
        """
        This function returns predicted label with weights of this model.
        Args:
            X_test (ndarray): 2d-array for feature matrix of test data.
        """
        proba = self.predict_proba(X_test)
        y_pred = np.argmax(proba, axis=1)
        return y_pred

# %%
import numpy as np

def find_w_with_gradient_descent_titanic(X, y):
    """
    >>> y, X = extract_target_array_feature_matrix_titanic()
    >>> w = find_w_with_gradient_descent_titanic(X, y)
    >>> w.shape
    (2,)
    """
    ### BEGIN SOLUTION

    ### END SOLUTION

# %% [markdown]
# ## 09. 載入 `titanic_test.csv`
#
# 定義函數 `import_titanic_test()` 將位於工作目錄的 `titanic_test.csv` 載入。
#
# 來源：<https://www.kaggle.com/c/titanic>

# %%
# !wget -Nq https://raw.githubusercontent.com/datainpoint/classroom-fintech-bot-2026/refs/heads/main/titanic_test.csv

# %%
import pandas as pd

def import_titanic_test():
    """
    >>> test = import_titanic_test()
    >>> test.shape
    (418, 11)
    """
    ### BEGIN SOLUTION

    ### END SOLUTION

# %% [markdown]
# ## 10. 以梯度遞減找出的 $w$ 預測 `titanic_test.csv`
#
# 定義函數 `predict_survived()` 能夠依據 `Sex` 與 $w$ 預測 `titanic_test.csv` 的 `Survived`

# %%
def predict_survived(X_test, w):
    """
    >>> y, X = extract_target_array_feature_matrix_titanic()
    >>> w = find_w_with_gradient_descent_titanic(X, y)
    >>> test = import_titanic_test()
    >>> X_test = test[["PassengerId", "Sex"]]
    >>> prediction = predict_survived(X_test, w)
    >>> prediction.shape
    (418, 2)
    >>> prediction.head()
       PassengerId  Survived
    0          892         0
    1          893         1
    2          894         0
    3          895         0
    4          896         1
    """
    ### BEGIN SOLUTION

    ### END SOLUTION

# %% [markdown]
# ## 練習題到此結束

# %%
import unittest
import numpy as np

def run_suite(test_class):
    suite = unittest.TestLoader().loadTestsFromTestCase(test_class)
    runner = unittest.TextTestRunner(verbosity=2)
    test_results = runner.run(suite)
    number_of_failures = len(test_results.failures)
    number_of_errors = len(test_results.errors)
    number_of_test_runs = test_results.testsRun
    number_of_successes = number_of_test_runs - (number_of_failures + number_of_errors)
    chapter_percentage = number_of_successes * 100 / number_of_test_runs
    print("你的練習題完成率為 ... {:.2f}% ({}/{})".format(chapter_percentage, number_of_successes, number_of_test_runs))

class TestDayFive(unittest.TestCase):
    def test_01(self):
        self.assertEqual(answer_01, 4)
    def test_02(self):
        self.assertEqual(answer_02, 4)
    def test_03(self):
        self.assertEqual(answer_03, 4)
    def test_04(self):
        self.assertEqual(answer_04, 3)
    def test_05(self):
        self.assertEqual(answer_05, 6)
    def test_06_import_titanic_train(self):
        train = import_titanic_train()
        self.assertEqual(train.shape, (891, 12))
    def test_07_extract_target_array_feature_matrix_titanic(self):
        y, X = extract_target_array_feature_matrix_titanic()
        self.assertEqual(y.shape, (891,))
        self.assertEqual(X.shape, (891, 1))
    def test_08_find_w_with_gradient_descent_titanic(self):
        y, X = extract_target_array_feature_matrix_titanic()
        w = find_w_with_gradient_descent_titanic(X, y)
        self.assertEqual(w.shape, (2,))
    def test_09_import_titanic_test(self):
        test = import_titanic_test()
        self.assertEqual(test.shape, (418, 11))
    def test_10_predict_survived(self):
        y, X = extract_target_array_feature_matrix_titanic()
        w = find_w_with_gradient_descent_titanic(X, y)
        test = import_titanic_test()
        X_test = test[["PassengerId", "Sex"]]
        prediction = predict_survived(X_test, w)
        self.assertEqual(prediction.shape, (418, 2))
        self.assertIn(0, prediction["Survived"])
        self.assertIn(1, prediction["Survived"])

run_suite(TestDayFive)
